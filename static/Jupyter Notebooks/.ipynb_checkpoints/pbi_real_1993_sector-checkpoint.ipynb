# %%
"|IMPORT PACKAGES|"
import pandas             as pd
import datetime
from   bokeh.plotting     import show, figure, output_file, save
from   bokeh.io           import show, output_notebook, curdoc, export_png
from   bokeh.models       import ColumnDataSource,LinearAxis, Range1d, NumeralTickFormatter, LabelSet, Label, BoxAnnotation, DatetimeTickFormatter, Legend, LegendItem
from   bokeh.models.tools import HoverTool

# %%
"|IMPORT DATA|"
path = r'https://github.com/ncachanosky/research/blob/master/Economic%20Series/'
file = r'Resumen%20Estadistico%20-%20Argentina.xlsx?raw=true'
IO   = path + file

sheet = 'PBI'

data = pd.read_excel(IO, sheet_name = sheet, usecols="EX:FS", skiprows=6, nrows=20, engine='openpyxl') # Be patient...

data.columns = ['YEAR',
                'A','B','C','D','E','F',
                'BIENES',
                'G','H','I','J','K','L','M','O',
                'SERVICIOS','INTERMEDIACION FINANCIERA','VA BRUTO','IVA','IMP IMPORTACIONES','PBI']

# %%
"|CHECK DATA|"         
data
# Out:
#     YEAR             A           B            C             D             E  \
# 0   1993  11736.940021  411.910069  3527.213214  43138.297938   4599.034278
# 1   1994  12652.803242  403.824472  4012.259368  45079.364321   5097.350148
# 2   1995  13380.018698  411.027930  4670.000240  41849.614225   5476.163429
# 3   1996  13167.155216  465.218328  4881.538549  44549.700173   5698.116857
# 4   1997  13194.737885  500.497960  4915.068966  48626.636381   6163.813990
# 5   1998  14444.730799  446.181333  4726.670868  49525.624271   6634.312047
# 6   1999  14824.411557  434.126292  4572.119786  45598.803211   6872.850252
# 7   2000  14567.049540  423.734060  4879.579200  43855.461424   7325.316842
# 8   2001  14612.295861  536.143848  5107.118687  40626.827855   7407.048903
# 9   2002  14369.710322  432.654769  4916.015030  36176.069201   7182.454748
# 10  2003  15381.779860  437.775970  5099.033141  41952.370162   7680.700146
# 11  2004  15223.503545  354.343687  5077.542793  46976.609543   8183.446395
# 12  2005  17004.914669  303.745971  5068.146162  50480.320868   8594.530403
# 13  2006  17264.767969  496.659526  5218.578967  54974.930862   9022.716477
# 14  2007  19037.054172  465.037917  5194.509338  59152.879189   9541.185368
# 15  2008  18522.971886  484.304260  5249.747452  61841.926921   9863.038792
# 16  2009  15601.416447  426.621289  5193.468905  61502.972459   9954.402299
# 17  2010  20046.019941  472.492735  5113.229345  67547.339311  10566.678110
# 18  2011  19557.437118  511.250338  4933.215238  74962.495945  11049.007573
# 19  2012  17342.129923  502.412470  4980.050477  74659.511436  11582.944796
#
#                F         BIENES             G             H  ...  \
# 0   13392.933031   76806.328551  33862.497194   5431.790643  ...
# 1   14163.906204   81409.507755  36044.623278   5894.082067  ...
# 2   12441.096860   78227.921382  33066.503886   5737.506647  ...
# 3   13491.540894   82253.270017  35556.766856   6309.271923  ...
# 4   15728.601446   89129.356628  39322.596089   7099.677741  ...
# 5   17094.670936   92872.190255  40450.696230   7551.435231  ...
# 6   15751.905118   88054.216216  37464.438480   7236.134715  ...
# 7   14284.167520   85335.308585  36386.752414   7235.899065  ...
# 8   12627.051186   80916.486341  33513.579600   6708.172430  ...
# 9    8409.599201   71486.503271  27324.935660   6152.190541  ...
# 16                4273.732764  355709.190372  25911.054795        5084.139565
# 17                4259.272533  386637.203778  28448.514892        7044.333491
# 18                5502.847705  418877.107305  32195.891438        8498.105953
# 19                6926.257571  426813.382290  33320.392363        8167.242145
#
#               PBI
# 0   236504.980232
# 1   250307.885536
# 2   243186.101519
# 3   256626.243056
# 4   277441.317622
# 5   288123.304608
# 6   278369.013872
# 7   276172.685353
# 8   263996.674367
# 9   235235.596753
# 10  256023.462375
# 11  279141.288632
# 12  304763.528550
# 13  330564.970472
# 14  359169.902946
# 15  383444.183250
# 16  386704.384733
# 17  422130.052161
# 18  459571.104696
# 19  468301.016798
#
# [20 rows x 22 columns]

# %%
"|BUILD PLOT|"

cds = ColumnDataSource(data)

colors=['black',     # 1
        'blue' ,     # 2
        'red'  ,     # 3
        'green',     # 4
        'slateblue', # 5
        'teal',      # 6
        'tan',       # 7
        'plum',      # 8
        'salmon',    # 9
        'orange',    #10
        'olive',     #11
        'maroon',    #12
        'lime',      #13
        'gold']      #14

legends=['Agricultura',                        # 1
         'Pesca',                              # 2
         'Minería',                            # 3
         'Manufacturas',                       # 4
         'Electricidad, gas, y agua',          # 5
         'Construcción',                       # 6
         'Comercio',                           # 7
         'Hoteles y restaurantes',             # 8
         'Transp., almacenamiento y comunic.', # 9
         'Intermediación financiera',          #10
         'Sector inmobiliario',                #11
         'Adm. pública y defensa',             #12
         'Educac., serv. socialies, y salud',  #13
         'Otros']                              #14
        
#BUILD FIGURE
p = figure(title = "PBI REAL (1993) POR SECTOR: VALOR AGREGADO BRUTO",
           y_axis_label = "Millones de pesos", 
           plot_height  = 600,
           plot_width   = 700)

p.toolbar_location = "above"
p.toolbar.autohide = True

#AXIS 1 (LEFT)
p1 = p.varea_stack(['A','B','C','D','E','F','G','H','I','J','K','L','M','O'], x='YEAR', color=colors, fill_alpha=0.5, muted_alpha=0.20, source=cds)
p2 = p.vline_stack(['A','B','C','D','E','F','G','H','I','J','K','L','M','O'], x='YEAR', color=colors, line_alpha=1.0, muted_alpha=0.20, source=cds)       

legend1 = Legend(items=[(legends[ 0], [p1[ 0]]),
                        (legends[ 1], [p1[ 1]]),
                        (legends[ 2], [p1[ 2]]),
                        (legends[ 3], [p1[ 3]]),
                        (legends[ 4], [p1[ 4]]),
                        (legends[ 5], [p1[ 5]])], orientation="horizontal", click_policy='mute')
                       
legend2 = Legend(items=[(legends[ 6], [p1[ 6]]),
                        (legends[ 7], [p1[ 7]]),
                        (legends[ 8], [p1[ 8]]),
                        (legends[ 9], [p1[ 9]]) ], orientation="horizontal", click_policy='mute')
                
legend3 = Legend(items=[(legends[10], [p1[10]]),
                        (legends[11], [p1[11]]),
                        (legends[12], [p1[12]]),
                        (legends[13], [p1[13]]) ], orientation="horizontal", click_policy='mute')


p.add_layout(legend1, "below")
p.add_layout(legend2, "below")
p.add_layout(legend3, "below")

p.yaxis[0].formatter = NumeralTickFormatter(format="$0,0")

show(p)

# %%
"|EXPORT .PNG FILE|"

export_png(p, filename="pbi_real_1993_sector.png")

# %%
"|# CREATE HTML FILE|"

output_file(filename="pbi_real_1993_sector.html", title="PBI real 1993 (sector)")
save(p)

# %%
"|CREATE JSON FILE|"
import json
import bokeh.embed

from bokeh.embed import json_item

j = json.dumps(json_item(p, "pbi_real_1993_sector"))
with open("pbi_real_1993_sector.json", "w") as fp:
    json.dump(j, fp)

# %%
"|CREATE SECTOR SHARES|"

data['TOTAL'] = data['A'] + data['B'] + data['C'] + data['D'] + data['E'] + data['F'] + data['G'] + data['H'] + \
                data['I'] + data['J'] + data['K'] + data['L'] + data['M'] + data['O']

data['A'] = data['A']/data['TOTAL'] * 100
data['B'] = data['B']/data['TOTAL'] * 100
data['C'] = data['C']/data['TOTAL'] * 100
data['D'] = data['D']/data['TOTAL'] * 100
data['E'] = data['E']/data['TOTAL'] * 100
data['F'] = data['F']/data['TOTAL'] * 100
data['G'] = data['G']/data['TOTAL'] * 100
data['H'] = data['H']/data['TOTAL'] * 100
data['I'] = data['I']/data['TOTAL'] * 100
data['J'] = data['J']/data['TOTAL'] * 100
data['K'] = data['K']/data['TOTAL'] * 100
data['L'] = data['L']/data['TOTAL'] * 100
data['M'] = data['M']/data['TOTAL'] * 100
data['O'] = data['O']/data['TOTAL'] * 100

data
# Out:
#     YEAR         A         B         C          D         E         F  \
# 0   1993  5.305817  0.186209  1.594517  19.501156  2.079046  6.054427
# 1   1994  5.384648  0.171855  1.707495  19.184405  2.169277  6.027727
# 2   1995  5.847402  0.179629  2.040906  18.289324  2.393220  5.437069
# 3   1996  5.461036  0.192948  2.024603  18.476846  2.363276  5.595573
# 4   1997  5.069140  0.192281  1.888266  18.681326  2.368007  6.042596
# 5   1998  5.309583  0.164007  1.737426  18.204589  2.438635  6.283645
# 6   1999  5.608550  0.164244  1.729779  17.251488  2.600219  5.959450
# 7   2000  5.548643  0.161402  1.858650  16.704706  2.790240  5.440892
# 8   2001  5.821643  0.213604  2.034713  16.186019  2.951021  5.030708
# 9   2002  6.358681  0.191452  2.175366  16.008123  3.178278  3.721297
# 10  2003  6.334392  0.180281  2.099840  17.276464  3.163000  4.653491
# 11  2004  5.801524  0.135037  1.935000  17.902313  3.118629  5.572571
# 12  2005  5.958025  0.106424  1.775730  17.686830  3.011272  6.168366
# 13  2006  5.584778  0.160659  1.688097  17.783199  2.918653  6.712470
# 14  2007  5.679127  0.138730  1.549624  17.646464  2.846323  6.803609
# 15  2008  5.196112  0.135858  1.472673  17.348057  2.766805  6.631896
# 16  2009  4.333932  0.118512  1.442699  17.084969  2.765243  6.317956
# 17  2010  5.128217  0.120874  1.308078  17.280110  2.703191  6.118102
# 18  2011  4.608473  0.120470  1.162452  17.664005  2.603565  6.146559
# 19  2012  3.998281  0.115833  1.148166  17.212979  2.670483  5.855113
#
#            BIENES          G         H  ...         L         M         O  \
# 0    76806.328551  15.307925  2.455502  ...  6.582952  8.218479  5.787116
# 1    81409.507755  15.339494  2.508342  ...  6.040034  7.915396  5.741481
# 2    78227.921382  14.450886  2.507433  ...  6.170210  8.342844  5.839425
# 3    82253.270017  14.747055  2.616750  ...  5.891973  8.216652  5.649831
# 14        5555.148061  359169.902946  335210.947429
# 15        6287.314696  383444.183250  356477.534500
# 16        5084.139565  386704.384733  359982.923136
# 17        7044.333491  422130.052161  390896.476312
# 18        8498.105953  459571.104696  424379.955010
# 19        8167.242145  468301.016798  433739.639860
#
# [20 rows x 23 columns]

# %%
"|BUILD PLOT|"

cds = ColumnDataSource(data)

colors=['black',     # 1
        'blue' ,     # 2
        'red'  ,     # 3
        'green',     # 4
        'slateblue', # 5
        'teal',      # 6
        'tan',       # 7
        'plum',      # 8
        'salmon',    # 9
        'orange',    #10
        'olive',     #11
        'maroon',    #12
        'lime',      #13
        'gold']      #14

legends=['Agricultura',                        # 1
         'Pesca',                              # 2
         'Minería',                            # 3
         'Manufacturas',                       # 4
         'Electricidad, gas, y agua',          # 5
         'Construcción',                       # 6
         'Comercio',                           # 7
         'Hoteles y restaurantes',             # 8
         'Transp., almacenamiento y comunic.', # 9
         'Intermediación financiera',          #10
         'Sector inmobiliario',                #11
         'Adm. pública y defensa',             #12
         'Educac., serv. socialies, y salud',  #13
         'Otros']                              #14
        
#BUILD FIGURE
p = figure(title = "PBI REAL (1993) PARTICIPACIóN POR SECTOR: VALOR AGREGADO BRUTO",
           y_axis_label = "Participación por sector", 
           y_range      = (0,100),
           plot_height  = 600,
           plot_width   = 700)

p.toolbar_location = "above"
p.toolbar.autohide = True

#AXIS 1 (LEFT)
p1 = p.varea_stack(['A','B','C','D','E','F','G','H','I','J','K','L','M','O'], x='YEAR', color=colors, fill_alpha=0.5, muted_alpha=0.20, source=cds)
p2 = p.vline_stack(['A','B','C','D','E','F','G','H','I','J','K','L','M','O'], x='YEAR', color=colors, line_alpha=1.0, muted_alpha=0.20, source=cds)       

legend1 = Legend(items=[(legends[ 0], [p1[ 0]]),
                        (legends[ 1], [p1[ 1]]),
                        (legends[ 2], [p1[ 2]]),
                        (legends[ 3], [p1[ 3]]),
                        (legends[ 4], [p1[ 4]]),
                        (legends[ 5], [p1[ 5]])], orientation="horizontal", click_policy='mute')
                       
legend2 = Legend(items=[(legends[ 6], [p1[ 6]]),
                        (legends[ 7], [p1[ 7]]),
                        (legends[ 8], [p1[ 8]]),
                        (legends[ 9], [p1[ 9]]) ], orientation="horizontal", click_policy='mute')
                
legend3 = Legend(items=[(legends[10], [p1[10]]),
                        (legends[11], [p1[11]]),
                        (legends[12], [p1[12]]),
                        (legends[13], [p1[13]]) ], orientation="horizontal", click_policy='mute')


p.add_layout(legend1, "below")
p.add_layout(legend2, "below")
p.add_layout(legend3, "below")

p.yaxis[0].formatter = NumeralTickFormatter(format="0,0")

show(p)

# %%
"|EXPORT .PNG FILE|"

export_png(p, filename="pbi_real_1993_sector_part.png")

# %%
"|# CREATE HTML FILE|"

output_file(filename="pbi_real_1993_sector_part.html", title="PBI real 1993 (participación x sector)")
save(p)

# %%
"|CREATE JSON FILE|"
import json
import bokeh.embed

from bokeh.embed import json_item

j = json.dumps(json_item(p, "pbi_real_1993_sector_part"))
with open("pbi_real_1993_sector_part.json", "w") as fp:
    json.dump(j, fp)
