# %%
"|IMPORT PACKAGES|"
import pandas             as pd
import datetime
from   bokeh.plotting     import show, figure, output_file, save
from   bokeh.io           import show, output_notebook, curdoc, export_png
from   bokeh.models       import ColumnDataSource,LinearAxis, Range1d, NumeralTickFormatter, LabelSet, Label, BoxAnnotation, DatetimeTickFormatter, Legend
from   bokeh.models.tools import HoverTool
from   bokeh.palettes     import Category20
from   bokeh.models       import Arrow, NormalHead, OpenHead, VeeHead
from   datetime           import datetime as dt

# %%
"|IMPORT DATA|"
path = r'https://github.com/ncachanosky/research/blob/master/Economic%20Series/'
file = r'Resumen%20Estadistico%20-%20Argentina.xlsx?raw=true'
IO   = path + file

sheet = 'ITCNM'

data = pd.read_excel(IO, sheet_name = sheet, usecols="A:P", skiprows=1, engine='openpyxl') # Be patient...

data = data.rename(columns={"Período"             :"MONTH"})
data = data.rename(columns={"ITCRM "              :"ITCRM"})
data = data.rename(columns={"ITCRB Brasil"        :"BRASIL"})
data = data.rename(columns={"ITCRB Canadá"        :"CANADA"})
data = data.rename(columns={"ITCRB Chile"         :"CHILE"})
data = data.rename(columns={"ITCRB Estados Unidos":"EEUU"})
data = data.rename(columns={"ITCRB México"        :"MEXICO"})
data = data.rename(columns={"ITCRB Uruguay"       :"URUGUAY"})
data = data.rename(columns={"ITCRB China"         :"CHINA"})
data = data.rename(columns={"ITCRB India"         :"INDIA"})
data = data.rename(columns={"ITCRB Japón"         :"JAPON"})
data = data.rename(columns={"ITCRB Reino Unido"   :"UK"})
data = data.rename(columns={"ITCRB Suiza"         :"SUIZA"})
data = data.rename(columns={"ITCRB Zona Euro"     :"EURO"})
data = data.rename(columns={"ITCRB Vietnam"       :"VIETNAM"})
data = data.rename(columns={"ITCRB Sudamérica*"   :"LATAM"})

# %%
"|CHECK DATA|"
data[200:250]
# Out:
#          MONTH  ITCRM  BRASIL  CANADA  CHILE   EEUU  MEXICO  URUGUAY  CHINA  \
# 200 2013-09-30   56.0    73.3    57.7   60.2   42.8    55.9     57.8   45.4
# 201 2013-10-31   58.3    77.5    58.8   61.7   43.6    57.4     60.3   46.4
# 202 2013-11-30   58.6    76.0    59.7   61.1   44.9    58.7     62.7   47.8
# 203 2013-12-31   61.4    78.4    62.1   63.4   47.3    62.1     66.1   50.5
# 204 2014-01-31   67.9    86.2    67.4   69.4   52.7    68.1     72.6   56.5
# 205 2014-02-28   75.3    95.7    74.0   74.9   58.6    75.3     78.2   62.5
# 206 2014-03-31   76.6    99.0    74.4   74.5   59.2    76.6     78.1   62.1
# 207 2014-04-30   78.5   104.0    75.8   76.1   59.7    78.0     78.0   62.2
# 208 2014-05-31   78.9   104.9    76.9   76.5   60.0    79.1     77.7   62.3
# 209 2014-06-30   79.5   105.6    78.1   77.6   60.6    79.7     78.8   63.1
# 210 2014-07-31   79.9   106.5    79.2   77.1   60.9    80.0     79.0   63.7
# 211 2014-08-31   80.5   106.5    79.3   75.8   62.1    80.7     78.1   65.4
# 212 2014-09-30   79.9   104.6    79.6   74.9   62.8    81.0     77.1   66.4
# 213 2014-10-31   78.8   100.5    78.7   76.1   63.2    80.1     77.5   66.9
# 214 2014-11-30   77.6    97.0    78.3   75.8   63.5    79.6     78.9   67.2
# 215 2014-12-31   76.3    93.8    77.2   73.8   63.8    74.8     79.0   66.8
# 216 2015-01-31   75.8    94.7    74.1   73.1   64.2    74.6     78.2   66.9
# 217 2015-02-28   74.5    89.5    72.3   73.8   64.8    74.2     78.6   67.2
# 218 2015-03-31   71.7    81.0    72.5   73.7   65.5    73.4     77.3   68.1
# 206   64.5   70.9   66.1   67.0   75.6     63.2   83.8
# 207   65.8   71.5   67.1   67.4   76.2     63.7   86.0
# 208   67.2   72.3   67.8   67.2   76.1     64.0   86.4
# 209   67.5   72.9   68.9   67.5   76.2     64.3   87.3
# 210   67.4   73.4   69.8   67.6   76.2     64.6   87.6
# 211   67.8   73.9   69.6   68.0   76.4     65.9   86.8
# 212   68.6   71.7   68.7   66.8   74.8     66.7   85.5
# 213   68.5   71.8   68.2   66.1   74.0     67.0   84.7
# 214   68.4   67.1   67.3   65.6   73.2     67.1   83.9
# 215   67.6   65.4   67.0   65.1   72.6     67.2   82.2
# 216   68.6   66.5   65.3   68.2   69.0     67.7   82.0
# 217   69.4   66.9   66.7   69.1   68.0     68.5   80.7
# 218   69.7   66.8   65.9   66.6   65.5     68.9   77.4
# 219   70.1   67.9   66.4   68.5   66.0     69.0   78.5
# 220   69.6   67.8   69.3   71.3   68.9     69.2   79.3
# 221   70.2   66.9   70.6   72.2   70.1     69.7   78.3
# 222   71.2   67.9   71.2   71.3   69.4     70.4   76.7
# 223   70.4   68.7   72.1   71.0   71.0     70.1   73.2
# 224   70.1   71.4   72.0   71.6   72.6     69.9   71.3
# 225   72.3   72.3   72.9   72.8   73.5     71.3   72.3
# 226   72.2   71.9   73.3   70.9   71.3     72.2   72.9
# 227   84.7   85.7   85.3   85.1   85.4     84.9   85.1
# 228  100.3  105.2   98.3  100.5  102.0    102.1   98.8
# 229  107.8  118.6  106.2  111.2  113.5    111.7  108.1
# 230  110.3  120.7  106.4  112.9  114.4    112.2  112.1
# 231  107.3  120.1  103.1  110.9  112.5    108.4  110.8
# 232  104.5  118.7  102.6  107.2  110.0    106.3  108.4
# 233  104.2  123.1  100.4  108.5  109.7    106.4  110.6
# 234  110.1  131.3   98.0  112.9  113.7    112.2  120.6
# 235  109.9  134.1   97.3  113.5  114.6    111.8  122.4
# 236  111.9  135.5   99.4  115.2  116.8    113.8  123.7
# 237  112.6  134.0   94.0  114.5  115.5    114.4  126.3
# 238  112.6  129.4   95.8  114.6  114.2    114.9  124.9
# 239  116.2  125.2   99.1  115.7  115.5    117.2  128.4
# 240  115.7  126.4   98.4  117.3  116.6    118.2  131.8
# 241  115.2  126.3   97.5  115.7  114.4    115.2  132.0
# 242  116.6  125.8   96.0  115.2  114.4    114.5  129.9
# 243  117.8  127.3   97.2  113.9  113.3    113.6  128.4
# 244  120.5  128.3  101.8  118.6  120.0    116.4  130.2
# 245  123.1  132.9  103.3  123.7  124.7    119.2  132.1
# 246  132.1  140.0  111.9  133.0  136.7    127.1  142.5
# 247  134.2  145.3  113.1  134.3  142.0    128.9  146.4
# 248  131.8  142.4  115.0  133.1  141.5    127.4  146.0
# 249  133.3  141.5  115.4  132.1  141.4    129.1  145.8

# %%
"|BUILD PLOT|"

cds    = ColumnDataSource(data)

#BUILD FIGURE
p = figure(title        = 'EL HUB ECONÓMICO | INDICE DE TIPO DE CAMBIO NOMINAL MULTILATERAL',
           x_axis_label = '',
           y_axis_label = '17-Ene-15 = 100',
           x_axis_type  = "datetime",
           y_axis_type  = "log",
           plot_height  = 400,
           plot_width   = 700)

p.xaxis[0].formatter = DatetimeTickFormatter(months="%b %Y")
p.toolbar_location = "right"
p.toolbar.autohide = True

#AXIS 1 (LEFT)
p1  = p.line("MONTH", "ITCRM"  , line_alpha=0.75, width=4, color="black"           , muted_alpha=0.20, source=cds)
p2  = p.line("MONTH", "BRASIL" , line_alpha=0.25, width=2, color=Category20[14][ 0], muted_alpha=0.10, source=cds)
p3  = p.line("MONTH", "CANADA" , line_alpha=0.25, width=2, color=Category20[14][ 1], muted_alpha=0.10, source=cds)
p4  = p.line("MONTH", "CHILE"  , line_alpha=0.25, width=2, color=Category20[14][ 2], muted_alpha=0.10, source=cds)
p5  = p.line("MONTH", "EEUU"   , line_alpha=0.25, width=2, color=Category20[14][ 3], muted_alpha=0.10, source=cds)
p6  = p.line("MONTH", "MEXICO" , line_alpha=0.25, width=2, color=Category20[14][ 4], muted_alpha=0.10, source=cds)
p7  = p.line("MONTH", "URUGUAY", line_alpha=0.25, width=2, color=Category20[14][ 5], muted_alpha=0.10, source=cds)
p8  = p.line("MONTH", "CHINA"  , line_alpha=0.25, width=2, color=Category20[14][ 6], muted_alpha=0.10, source=cds)
p9  = p.line("MONTH", "INDIA"  , line_alpha=0.25, width=2, color=Category20[14][ 7], muted_alpha=0.10, source=cds)
p10 = p.line("MONTH", "JAPON"  , line_alpha=0.25, width=2, color=Category20[14][ 8], muted_alpha=0.10, source=cds)
p11 = p.line("MONTH", "UK"     , line_alpha=0.25, width=2, color=Category20[14][ 9], muted_alpha=0.10, source=cds)
p12 = p.line("MONTH", "SUIZA"  , line_alpha=0.25, width=2, color=Category20[14][10], muted_alpha=0.10, source=cds)
p13 = p.line("MONTH", "EURO"   , line_alpha=0.25, width=2, color=Category20[14][11], muted_alpha=0.10, source=cds)
p14 = p.line("MONTH", "VIETNAM", line_alpha=0.25, width=2, color=Category20[14][12], muted_alpha=0.10, source=cds)
p15 = p.line("MONTH", "LATAM"  , line_alpha=0.25, width=2, color=Category20[14][13], muted_alpha=0.10, source=cds)

p.add_tools(HoverTool(renderers=[p1], tooltips = [("ITCNM", "@ITCRM{0.0}")], mode="vline"))

#LEGEND
legend = Legend(items=[
    ("ITCRM"         , [p1]),
    ("Brasil"        , [p2]),
    ("Canadá"        , [p3]),
    ("Chile"         , [p4]),
    ("Estados Unidos", [p5]),
    ("México"        , [p6]),
    ("Uruguay"       , [p7]),
    ("China"         , [p8]),
    ("India"         , [p9]),
    ("Japón"         , [p10]),
    ("Reino Unido"   , [p11]),
    ("Suiza"         , [p12]),
    ("Zona Euro"     , [p13]),
    ("Vietnam"       , [p14]),
    ("Sudamérica"    , [p15]) ], location="center")

p.add_layout(legend, 'right')

show(p)

# %%
"|EXPORT .PNG FILE|"

export_png(p, filename="itcnm.png")

# %%
"|# CREATE HTML FILE|"

output_file(filename="itcnm.html", title="ITCNM")
save(p)

# %%
"|CREATE JSON FILE|"
import json
import bokeh.embed

from bokeh.embed import json_item

j = json.dumps(json_item(p, "itcnm"))
with open("itcnm.json", "w") as fp:
    json.dump(j, fp)
